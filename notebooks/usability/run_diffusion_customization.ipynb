# %% [markdown]
# # Multipaths Usage and Customization

# %%
import os
import numpy as np
import pandas as pd

from diffupath.constants import ROOT_RESULTS_DIR

# %% [markdown]
# ## DiffuPy

# %%
GRAPH_PATH = os.path.join(ROOT_RESULTS_DIR, 'data', 'graphs', '_graph.gml')
DATA_INPUT_PATH = os.path.join(ROOT_RESULTS_DIR, 'data', 'input_samples', 'input_sample_3.csv')

# %% [markdown]
# #### Input Dataset overview

# %%
from diffupy.process_input import process_input_data

# %%
input_labels = process_input_data(DATA_INPUT_PATH)
pd.DataFrame(index = input_labels.keys(), data={'scores':list(input_labels.values())})
# Out:
#     scores
# V1    1.81
# V2    1.86
# V3    4.82
# V4    1.64
# V9    1.53

# %% [markdown]
# #### Graph overview

# %%
from diffupy.process_network import process_graph_from_file

import networkx as nx
import matplotlib.pyplot as plt

# %%
g = nx.read_gml(GRAPH_PATH, label='name')
fig, ax = plt.subplots(1, 1, figsize=(8, 6));
nx.draw_networkx(g, ax=ax)

# %% [markdown]
# ### Run basic diffusion

# %%
from diffupy.diffuse import run_diffusion

run_diffusion(DATA_INPUT_PATH, GRAPH_PATH).as_pd_dataframe() #DATA INPUT and GRAPH as PATHs
# Out:
# Mapping coverage statistics
#
# total:
# (5, 1.0)
# /Users/Projects/MultiPath/diffuPy/src/diffupy/matrix.py:512: FutureWarning: set_axis currently defaults to operating inplace.
# This will change in a future version of pandas, use inplace=True to avoid this warning.
#   df.set_axis(rows_labels)
#      output diffusion scores
# V1                  5.101629
# V2                  4.651528
# V4                  4.550666
# V3                  4.473349
# V9                  3.449531
# V8                  0.693661
# V43                 0.652997
# V23                 0.516627
# V5                  0.507484
# V27                 0.447959
# V34                 0.395177
# V57                 0.340320
# V12                 0.335155
# V10                 0.298916
# V6                  0.292107
# V80                 0.278509
# V49                 0.258448
# V7                  0.256355
# V20                 0.218897
# V16                 0.186528
# V17                 0.168614
# V98                 0.151327
# V54                 0.141103
# V35                 0.132926
# V14                 0.128830
# V13                 0.112556
# V40                 0.099276
# V96                 0.078441
# V78                 0.077314
# V95                 0.054971
# ..                       ...
# V84                -0.246297
# V76                -0.254292
# V97                -0.262298
# V72                -0.263465
# V94                -0.269682
# V83                -0.274735
# V82                -0.275463
# V46                -0.275644
# V67                -0.278223
# V73                -0.279922
# V19                -0.280088
# V68                -0.282752
# V79                -0.287725
# V66                -0.294628
# V63                -0.294663
# V89                -0.294915
# V62                -0.304904
# V21                -0.318269
# V64                -0.322181
# V30                -0.326642
# V77                -0.337865
# V81                -0.345486
# V91                -0.351873
# V88                -0.367517
# V36                -0.372467
# V38                -0.398399
# V41                -0.406258
# V53                -0.478751
# V39                -0.518628
# V29                -0.552754
#
# [100 rows x 1 columns]

# %%
run_diffusion(input_labels, g).as_pd_dataframe() #DATA INPUT and GRAPH as Python OBJECTS
# Out:
# Mapping coverage statistics
#
# total:
# (5, 1.0)
#      output diffusion scores
# V1                  5.101629
# V2                  4.651528
# V4                  4.550666
# V3                  4.473349
# V9                  3.449531
# V8                  0.693661
# V43                 0.652997
# V23                 0.516627
# V5                  0.507484
# V27                 0.447959
# V34                 0.395177
# V57                 0.340320
# V12                 0.335155
# V10                 0.298916
# V6                  0.292107
# V80                 0.278509
# V49                 0.258448
# V7                  0.256355
# V20                 0.218897
# V16                 0.186528
# V17                 0.168614
# V98                 0.151327
# V54                 0.141103
# V35                 0.132926
# V14                 0.128830
# V13                 0.112556
# V40                 0.099276
# V96                 0.078441
# V78                 0.077314
# V95                 0.054971
# ..                       ...
# V84                -0.246297
# V76                -0.254292
# V97                -0.262298
# V72                -0.263465
# V94                -0.269682
# V83                -0.274735
# V82                -0.275463
# V46                -0.275644
# V67                -0.278223
# V73                -0.279922
# V19                -0.280088
# V68                -0.282752
# V79                -0.287725
# V66                -0.294628
# V63                -0.294663
# V89                -0.294915
# V62                -0.304904
# V21                -0.318269
# V64                -0.322181
# V30                -0.326642
# V77                -0.337865
# V81                -0.345486
# V91                -0.351873
# V88                -0.367517
# V36                -0.372467
# V38                -0.398399
# V41                -0.406258
# V53                -0.478751
# V39                -0.518628
# V29                -0.552754
#
# [100 rows x 1 columns]

# %% [markdown]
# ### Customize diffusion method

# %% [markdown]
# #### Available methods

# %%
run_diffusion(DATA_INPUT_PATH, GRAPH_PATH, method = 'z').as_pd_dataframe()
# Out:
# Mapping coverage statistics
#
# total:
# (5, 1.0)
#      output diffusion scores
# V1                  5.101629
# V2                  4.651528
# V4                  4.550666
# V3                  4.473349
# V9                  3.449531
# V8                  0.693661
# V43                 0.652997
# V23                 0.516627
# V5                  0.507484
# V27                 0.447959
# V34                 0.395177
# V57                 0.340320
# V12                 0.335155
# V10                 0.298916
# V6                  0.292107
# V80                 0.278509
# V49                 0.258448
# V7                  0.256355
# V20                 0.218897
# V16                 0.186528
# V17                 0.168614
# V98                 0.151327
# V54                 0.141103
# V35                 0.132926
# V14                 0.128830
# V13                 0.112556
# V40                 0.099276
# V96                 0.078441
# V78                 0.077314
# V95                 0.054971
# ..                       ...
# V84                -0.246297
# V76                -0.254292
# V97                -0.262298
# V72                -0.263465
# V94                -0.269682
# V83                -0.274735
# V82                -0.275463
# V46                -0.275644
# V67                -0.278223
# V73                -0.279922
# V19                -0.280088
# V68                -0.282752
# V79                -0.287725
# V66                -0.294628
# V63                -0.294663
# V89                -0.294915
# V62                -0.304904
# V21                -0.318269
# V64                -0.322181
# V30                -0.326642
# V77                -0.337865
# V81                -0.345486
# V91                -0.351873
# V88                -0.367517
# V36                -0.372467
# V38                -0.398399
# V41                -0.406258
# V53                -0.478751
# V39                -0.518628
# V29                -0.552754
#
# [100 rows x 1 columns]

# %%
run_diffusion(DATA_INPUT_PATH, GRAPH_PATH, method = 'raw').as_pd_dataframe()
# Out:
# Mapping coverage statistics
#
# total:
# (5, 1.0)
#      output diffusion scores
# V1                 -0.623638
# V2                 -0.693434
# V4                 -0.752424
# V3                 -0.776944
# V9                 -0.777572
# V23                -0.840882
# V43                -0.847838
# V27                -0.854532
# V34                -0.855078
# V57                -0.860645
# V8                 -0.866778
# V80                -0.867373
# V49                -0.873112
# V10                -0.880527
# V98                -0.881099
# V12                -0.882527
# V54                -0.882623
# V5                 -0.884105
# V16                -0.885716
# V20                -0.888065
# V35                -0.888223
# V40                -0.888541
# V17                -0.890376
# V6                 -0.890943
# V96                -0.890959
# V78                -0.891209
# V14                -0.893114
# V7                 -0.893150
# V75                -0.893436
# V55                -0.893517
# ..                       ...
# V72                -0.926330
# V46                -0.926476
# V29                -0.926699
# V45                -0.926792
# V38                -0.927336
# V85                -0.927718
# V30                -0.928097
# V53                -0.929437
# V87                -0.929470
# V59                -0.930377
# V97                -0.930550
# V84                -0.930745
# V76                -0.932176
# V73                -0.933154
# V82                -0.933245
# V68                -0.933954
# V39                -0.934272
# V94                -0.934549
# V66                -0.934795
# V89                -0.935664
# V81                -0.935728
# V63                -0.935886
# V67                -0.936269
# V83                -0.937184
# V36                -0.937215
# V77                -0.937378
# V64                -0.939181
# V41                -0.944127
# V91                -0.944257
# V88                -0.948285
#
# [100 rows x 1 columns]

# %% [markdown]
# #### Custom method

# %%
import networkx as nx

run_diffusion(DATA_INPUT_PATH, GRAPH_PATH, method = nx.pagerank)
# Out:
# {0: 0.01215561487407176,
#  1: 0.01846784512517859,
#  2: 0.03468910151755468,
#  3: 0.025367286032752807,
#  4: 0.029195140002494138,
#  5: 0.031047124960312596,
#  6: 0.03324268077083303,
#  7: 0.017242231150300262,
#  8: 0.026677440168268063,
#  9: 0.011326871216906785,
#  10: 0.019203874844964525,
#  11: 0.015998264328250952,
#  12: 0.027755631572553573,
#  13: 0.016292314709265367,
#  14: 0.005458163147682142,
#  15: 0.010181535405135287,
#  16: 0.014656696589778924,
#  17: 0.012095650510682187,
#  18: 0.01923750041987516,
#  19: 0.016274039943300622,
#  20: 0.014774554074368437,
#  21: 0.016209770866960467,
#  22: 0.005374537917686662,
#  23: 0.016420093202120848,
#  24: 0.011866057983655654,
#  25: 0.014915622291522703,
#  26: 0.007193681835897376,
#  27: 0.005581184057216518,
#  28: 0.01959896007705464,
#  29: 0.008634213461316171,
#  30: 0.005604370886540591,
#  31: 0.008779852509082354,
#  32: 0.00552663808462073,
#  33: 0.005370092525070027,
#  34: 0.008797593432541946,
#  35: 0.007294723997574731,
#  36: 0.005602732004612746,
#  37: 0.012014130965302006,
#  38: 0.013839556268039515,
#  39: 0.00547307563020587,
#  40: 0.0076821577770942,
#  41: 0.007336398564346497,
#  42: 0.010239627378298696,
#  43: 0.008748719567458185,
#  44: 0.0073902870484233414,
#  45: 0.0070030995137418195,
#  46: 0.010187248737942068,
#  47: 0.008759517132805365,
#  48: 0.007311242159125562,
#  49: 0.007229929390308358,
#  50: 0.005846270409936342,
#  51: 0.007112647922149048,
#  52: 0.015382900950905009,
#  53: 0.005725342074248175,
#  54: 0.005613286631669019,
#  55: 0.005611078372670239,
#  56: 0.005499624810923529,
#  57: 0.007335683877620333,
#  58: 0.005901515703811987,
#  59: 0.008777322118970561,
#  60: 0.005884229261994816,
#  61: 0.010573454093931463,
#  62: 0.00571042911202012,
#  63: 0.005820274585706898,
#  64: 0.00564817499261692,
#  65: 0.00566819784725121,
#  66: 0.0060092981425760505,
#  67: 0.00575101339572618,
#  68: 0.007280801293116766,
#  69: 0.010396788255946726,
#  70: 0.007276902885618289,
#  71: 0.0071934784281207885,
#  72: 0.005649022510675034,
#  73: 0.005632332284449832,
#  74: 0.005684232512335796,
#  75: 0.005860576238343652,
#  76: 0.007713483828818389,
#  77: 0.0054642816685462016,
#  78: 0.009037484866584176,
#  79: 0.005557055358395377,
#  80: 0.007348292774075349,
#  81: 0.005745169595648116,
#  82: 0.0060263522695349426,
#  83: 0.005729312488283791,
#  84: 0.005834759415813681,
#  85: 0.0055491423398846395,
#  86: 0.005642577675772223,
#  87: 0.006129381607329851,
#  88: 0.005774674224256528,
#  89: 0.005554526926454343,
#  90: 0.005918581810415264,
#  91: 0.005742882016272388,
#  92: 0.005602648110565285,
#  93: 0.005975681961894002,
#  94: 0.0054797253146465314,
#  95: 0.005503182384932178,
#  96: 0.005532884982976012,
#  97: 0.005798611725484809,
#  98: 0.005681600445966422,
#  99: 0.005488150863019249}

# %% [markdown]
# ### Customize kernel calculation

# %%
from diffupy.kernels import p_step_kernel

# %%
run_diffusion(DATA_INPUT_PATH, GRAPH_PATH, kernel_method = p_step_kernel).as_pd_dataframe()
# Out:
# Mapping coverage statistics
#
# total:
# (5, 1.0)
#      output diffusion scores
# V1                  5.914873
# V3                  5.436125
# V2                  4.995087
# V23                 4.799158
# V4                  4.761921
# V34                 4.433335
# V9                  3.688642
# V57                 3.615167
# V80                 2.975798
# V43                 2.588200
# V27                 2.539197
# V40                 2.497171
# V78                 2.213486
# V96                 2.196625
# V54                 2.134597
# V8                  2.127574
# V95                 2.121935
# V5                  1.980929
# V10                 1.941319
# V49                 1.849088
# V7                  1.822112
# V12                 1.808996
# V6                  1.707308
# V37                 1.683145
# V55                 1.635673
# V16                 1.597624
# V74                 1.553578
# V86                 1.552385
# V93                 1.493676
# V98                 1.458388
# ..                       ...
# V45                 0.144830
# V79                 0.124148
# V76                 0.086180
# V72                 0.051446
# V94                 0.050200
# V87                 0.039703
# V62                 0.013485
# V84                 0.006050
# V83                -0.025394
# V97                -0.083351
# V68                -0.084122
# V82                -0.087403
# V67                -0.092574
# V46                -0.117645
# V77                -0.189971
# V30                -0.200752
# V73                -0.206062
# V89                -0.226144
# V66                -0.287913
# V38                -0.306933
# V63                -0.316810
# V53                -0.347628
# V81                -0.406990
# V64                -0.431073
# V29                -0.450004
# V88                -0.479800
# V36                -0.501865
# V41                -0.517637
# V91                -0.526563
# V39                -0.562620
#
# [100 rows x 1 columns]

# %% [markdown]
# ## DiffuPath

# %%
DATA_INPUT_PATH = os.path.join(ROOT_RESULTS_DIR, 'data', 'input_samples', 'input_sample_1.csv')

# %%
input_labels = process_input_data(DATA_INPUT_PATH)
pd.DataFrame(index = input_labels.keys(), data={'scores':list(input_labels.values())})
# Out:
#             scores
# MANF          1.81
# MARS          1.86
# AGR2          4.82
# Isoleucine    1.64
# Alanine       1.53

# %%
from diffupath.cli import run_diffupath
run_diffupath(input_labels).as_pd_dataframe() #DATA INPUT as PATHs
# Out:
# Usage: ipykernel_launcher.py [OPTIONS]
# Try "ipykernel_launcher.py --help" for help.
#
# Error: Got unexpected extra arguments (MANF MARS AGR2 Isoleucine Alanine)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
